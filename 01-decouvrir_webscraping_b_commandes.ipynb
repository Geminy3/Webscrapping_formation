# %% [markdown]
# # Récapitulatif des principales balises HTML
#
#   **Catégorie**         | **Balise**       | **Description**                                                                 | **Exemple**                                  | **Fermeture** |
#  |-----------------------|------------------|---------------------------------------------------------------------------------|----------------------------------------------|---------------|
#  | **Structure**         | `<!DOCTYPE html>` | Déclare le type de document (HTML5).                                          | `<!DOCTYPE html>`                            | Non           |
#  |                       | `<html>`         | Racine du document HTML.                                                       | `<html>...</html>`                           | Oui           |
#  |                       | `<head>`         | Contient les métadonnées (titres, styles, scripts).                           | `<head>...</head>`                           | Oui           |
#  |                       | `<body>`         | Contient le contenu visible de la page.                                       | `<body>...</body>`                           | Oui           |
#  |                       | `<title>`        | Titre de la page (affiché dans l'onglet du navigateur).                       | `<title>Ma Page</title>`                     | Oui           |
#  |                       | `<meta>`         | Métadonnées (encodage, viewport, etc.).                                       | `<meta charset="UTF-8">`                     | Non           |
#  | **Texte**            | `<h1>` à `<h6>`  | Titres de niveau 1 à 6.                                                        | `<h1>Titre principal</h1>`                  | Oui           |
#  |                       | `<p>`            | Paragraphe.                                                                    | `<p>Un paragraphe.</p>`                      | Oui           |
#  |                       | `<br>`           | Saut de ligne.                                                                 | `Texte<br>Nouvelle ligne`                    | Non           |
#  |                       | `<hr>`           | Ligne horizontale (séparation thématique).                                    | `<hr>`                                        | Non           |
#  |                       | `<strong>`       | Texte en **gras** (importance sémantique).                                     | `<strong>Important</strong>`                 | Oui           |
#  |                       | `<b>`            | Texte en **gras** (style uniquement).                                         | `<b>Gras</b>`                                | Oui           |
#  |                       | `<em>`           | Texte en *italique* (emphase sémantique).                                     | `<em>Emphase</em>`                            | Oui           |
#  |                       | `<i>`            | Texte en *italique* (style uniquement).                                       | `<i>Italique</i>`                             | Oui           |
#  |                       | `<mark>`         | Texte surligné (marqué).                                                       | `<mark>Surligné</mark>`                      | Oui           |
#  |                       | `<small>`        | Texte en petit.                                                                | `<small>Petit texte</small>`                  | Oui           |
#  |                       | `<sub>`          | Indice (exposant inférieur).                                                   | `H<sub>2</sub>O`                            | Oui           |
#  |                       | `<sup>`          | Exposant.                                                                      | `x<sup>2</sup>`                              | Oui           |
#  |                       | `<code>`         | Code source (monospace).                                                       | `<code>console.log()</code>`                 | Oui           |
#  |                       | `<pre>`          | Texte préformaté (conserve les espaces et sauts de ligne).                     | `<pre>  Code\n  formaté</pre>`               | Oui           |
#  |                       | `<blockquote>`   | Citation longue.                                                               | `<blockquote>Citation</blockquote>`          | Oui           |
#  |                       | `<q>`            | Citation courte (entre guillemets).                                           | `<q>Citation courte</q>`                     | Oui           |
#  | **Listes**           | `<ul>`           | Liste non ordonnée.                                                           | `<ul><li>Élément</li></ul>`                  | Oui           |
#  |                       | `<ol>`           | Liste ordonnée.                                                               | `<ol><li>Premier</li></ol>`                  | Oui           |
#  |                       | `<li>`           | Élément de liste.                                                              | `<li>Élément</li>`                           | Oui           |
#  |                       | `<dl>`           | Liste de définitions.                                                          | `<dl><dt>Terme</dt><dd>Définition</dd></dl>` | Oui           |
#  |                       | `<dt>`           | Terme dans une liste de définitions.                                           | `<dt>Terme</dt>`                             | Oui           |
#  |                       | `<dd>`           | Définition dans une liste de définitions.                                     | `<dd>Définition</dd>`                        | Oui           |
#  | **Liens & Médias**   | `<a>`            | Lien hypertexte.                                                               | `<a href="url">Lien</a>`                     | Oui           |
#  |                       | `<img>`          | Image.                                                                         | `<img src="image.jpg" alt="Description">`     | Non           |
#  |                       | `<audio>`        | Audio.                                                                         | `<audio src="audio.mp3" controls></audio>`    | Oui           |
#  |                       | `<video>`        | Vidéo.                                                                         | `<video src="video.mp4" controls></video>`   | Oui           |
#  |                       | `<source>`       | Source pour `<audio>` ou `<video>`.                                            | `<source src="video.mp4" type="video/mp4">`  | Non           |
#  |                       | `<figure>`       | Conteneur pour une image, vidéo, etc. avec légende.                            | `<figure><img src="..."><figcaption>...</figcaption></figure>` | Oui |
#  |                       | `<figcaption>`   | Légende pour `<figure>`.                                                       | `<figcaption>Légende</figcaption>`           | Oui           |
#  | **Tableaux**         | `<table>`        | Tableau.                                                                       | `<table>...</table>`                         | Oui           |
#  |                       | `<tr>`           | Ligne de tableau.                                                              | `<tr><td>Cellule</td></tr>`                  | Oui           |
#  |                       | `<th>`           | En-tête de tableau.                                                            | `<th>En-tête</th>`                           | Oui           |
#  |                       | `<td>`           | Cellule de tableau.                                                            | `<td>Donnée</td>`                            | Oui           |
#  |                       | `<thead>`        | Groupe d'en-têtes de tableau.                                                  | `<thead><tr><th>...</th></tr></thead>`       | Oui           |
#  |                       | `<tbody>`        | Corps du tableau.                                                              | `<tbody>...</tbody>`                         | Oui           |
#  |                       | `<tfoot>`        | Pied de tableau.                                                               | `<tfoot>...</tfoot>`                         | Oui           |
#  | **Formulaires**      | `<form>`         | Formulaire.                                                                    | `<form action="/submit" method="post">...</form>` | Oui       |
#  |                       | `<input>`        | Champ de saisie (texte, mot de passe, etc.).                                   | `<input type="text" name="nom">`              | Non           |
#  |                       | `<label>`        | Étiquette pour un champ de formulaire.                                         | `<label for="nom">Nom :</label>`             | Oui           |
#  |                       | `<textarea>`     | Zone de texte multiligne.                                                      | `<textarea name="message"></textarea>`       | Oui           |
#  |                       | `<button>`       | Bouton.                                                                         | `<button type="submit">Envoyer</button>`     | Oui           |
#  |                       | `<select>`       | Liste déroulante.                                                              | `<select><option>Option</option></select>`   | Oui           |
#  |                       | `<option>`       | Option dans une liste déroulante.                                              | `<option value="val">Option</option>`        | Oui           |
#  |                       | `<optgroup>`     | Groupe d'options dans une liste déroulante.                                    | `<optgroup label="Groupe">...</optgroup>`    | Oui           |
#  |                       | `<fieldset>`     | Groupe de champs de formulaire.                                                | `<fieldset><legend>Titre</legend>...</fieldset>` | Oui       |
#  |                       | `<legend>`       | Titre pour `<fieldset>`.                                                       | `<legend>Informations</legend>`              | Oui           |
#  | **Semantique**       | `<header>`       | En-tête de page ou section.                                                    | `<header>...</header>`                       | Oui           |
#  |                       | `<footer>`       | Pied de page ou section.                                                       | `<footer>...</footer>`                       | Oui           |
#  |                       | `<nav>`          | Section de navigation.                                                        | `<nav>...</nav>`                             | Oui           |
#  |                       | `<main>`         | Contenu principal de la page.                                                 | `<main>...</main>`                           | Oui           |
#  |                       | `<article>`      | Contenu autonome (article, commentaire, etc.).                                | `<article>...</article>`                     | Oui           |
#  |                       | `<section>`      | Section thématique.                                                            | `<section>...</section>`                     | Oui           |
#  |                       | `<aside>`        | Contenu secondaire (barre latérale, etc.).                                     | `<aside>...</aside>`                         | Oui           |
#  |                       | `<div>`          | Conteneur générique (sans sémantique).                                         | `<div>...</div>`                             | Oui           |
#  |                       | `<span>`         | Conteneur générique en ligne.                                                  | `<span>...</span>`                           | Oui           |
#  | **Script & Style**   | `<script>`       | Code JavaScript.                                                               | `<script>alert("Hello");</script>`           | Oui           |
#  |                       | `<style>`        | CSS intégré.                                                                   | `<style>body { color: red; }</style>`        | Oui           |
#  |                       | `<link>`         | Lien vers une ressource externe (CSS, etc.).                                   | `<link rel="stylesheet" href="styles.css">`  | Non           |
#  | **Autres**           | `<!-- -->`      | Commentaire (non affiché).                                                     | `<!-- Commentaire -->`                        | Non           |
#  |                       | `<iframe>`       | Intègre une page web externe.                                                  | `<iframe src="url"></iframe>`                | Oui           |
#  |                       | `<details>`      | Section dépliable.                                                             | `<details><summary>Titre</summary>...</details>` | Oui       |
#  |                       | `<summary>`      | Titre pour `<details>`.                                                        | `<summary>Cliquez pour afficher</summary>`   | Oui           |
#  |                       | `<progress>`     | Barre de progression.                                                          | `<progress value="50" max="100"></progress>` | Oui           |
#  |                       | `<meter>`        | Jauge (plage de valeurs).                                                      | `<meter value="0.6">60%</meter>`            | Oui           |

# %% [markdown]
# # Principaux attributs des balises HTML
#
#   **Catégorie**               | **Attribut**               | **Description**                                                                                     | **Balises associées**                          | **Valeurs/Exemples**                                                                                     | **HTML5** |
#  |-----------------------------|----------------------------|-----------------------------------------------------------------------------------------------------|-----------------------------------------------|----------------------------------------------------------------------------------------------------------|-----------|
#  | **⚡ Attributs globaux**     | `id`                       | Identifiant **unique** pour un élément (utilisé en CSS/JS).                                         | Toutes                                         | `id="header"`                                                                                         | Oui       |
#  |                             | `class`                    | Classe(s) pour le style (CSS) ou la sélection (JS).                                               | Toutes                                         | `class="btn primary"` (plusieurs classes séparées par des espaces)                                   | Oui       |
#  |                             | `style`                    | Styles CSS **en ligne**.                                                                           | Toutes                                         | `style="color: red; font-size: 16px;"`                                                                | Oui       |
#  |                             | `title`                    | Info-bulle (tooltip) au survol.                                                                     | Toutes                                         | `title="Ceci est un bouton"`                                                                          | Oui       |
#  |                             | `lang`                     | Langue du contenu.                                                                                 | Toutes (surtout `<html>`, `<p>`, `<span>`)      | `lang="fr"`, `lang="en-US"`                                                                          | Oui       |
#  |                             | `data-*`                  | Attributs personnalisés (pour JavaScript).                                                         | Toutes                                         | `data-user-id="123"`, `data-role="admin"` (accessibles via `element.dataset.userId`)               | Oui       |
#  |                             | `tabindex`                 | Ordre de tabulation (accessibilité).                                                               | Toutes                                         | `tabindex="1"` (focusable), `tabindex="-1"` (non focusable mais accessible via JS)                     | Oui       |
#  |                             | `hidden`                   | Masque l'élément (équivalent à `display: none;` en CSS).                                           | Toutes                                         | `hidden` (pas de valeur)                                                                             | Oui       |
#  |                             | `dir`                      | Direction du texte.                                                                               | Toutes                                         | `dir="ltr"` (gauche à droite), `dir="rtl"` (droite à gauche), `dir="auto"`                           | Oui       |
#  |                             | `accesskey`                | Raccourci clavier pour accéder à l'élément.                                                        | Toutes (sauf `<base>`, `<bdo>`, `<br>`, etc.) | `accesskey="s"` (Alt+S sur Windows)                                                                   | Oui       |
#  |                             | `draggable`                | Autorise le glisser-déposer.                                                                       | Toutes                                         | `draggable="true"` ou `false`                                                                         | Oui       |
#  |                             | `spellcheck`               | Active la vérification orthographique.                                                           | `<input>`, `<textarea>`, éléments éditables   | `spellcheck="true"` (défaut) ou `false`                                                               | Oui       |
#  | **🔗 Liens & Navigation**   | `href`                      | URL de destination pour un lien.                                                                  | `<a>`, `<link>`, `<area>`                     | `href="https://example.com"`, `href="#section"`, `href="mailto:contact@example.com"`               | Oui       |
#  |                             | `target`                    | Où ouvrir le lien.                                                                                 | `<a>`, `<form>`, `<area>`                     | `_self` (défaut), `_blank` (nouvel onglet), `_parent`, `_top`, `nom-de-fenêtre`                     | Oui       |
#  |                             | `rel`                       | Relation entre la page et la ressource liée.                                                     | `<a>`, `<link>`, `<area>`                     | `rel="nofollow"` (SEO), `rel="noopener noreferrer"` (sécurité pour `_blank`), `rel="stylesheet"` (CSS) | Oui       |
#  |                             | `download`                  | Force le téléchargement au clic.                                                                   | `<a>`, `<area>`                                | `download` ou `download="nom-fichier.pdf"`                                                          | Oui       |
#  |                             | `hreflang`                  | Langue de la ressource liée.                                                                       | `<a>`, `<link>`, `<area>`                     | `hreflang="en"`                                                                                      | Oui       |
#  | **🖼️ Images & Médias**      | `src`                       | Source (URL) de l'image/média.                                                                     | `<img>`, `<audio>`, `<video>`, `<source>`, `<iframe>`, `<script>` | `src="image.jpg"`                                                                                   | Oui       |
#  |                             | `alt`                       | Texte alternatif (accessibilité).                                                                 | `<img>`, `<area>`                              | `alt="Description de l'image"` (obligatoire pour l'accessibilité)                                  | Oui       |
#  |                             | `width` / `height`           | Dimensions de l'image/média (en pixels).                                                          | `<img>`, `<video>`, `<canvas>`, `<svg>`       | `width="200"`, `height="auto"`                                                                       | Oui       |
#  |                             | `loading`                   | Contrôle le chargement différé (lazy loading).                                                    | `<img>`, `<iframe>`                           | `loading="lazy"` (chargement au scroll), `eager` (défaut)                                             | Oui       |
#  |                             | `decoding`                  | Mode de décodage de l'image.                                                                       | `<img>`                                        | `decoding="async"` (défaut), `sync`, `auto`                                                          | Oui       |
#  |                             | `srcset`                    | Liste de sources pour les images responsives.                                                     | `<img>`, `<source>` (dans `<picture>`)          | `srcset="image-480w.jpg 480w, image-800w.jpg 800w"`                                                  | Oui       |
#  |                             | `sizes`                     | Taille de l'image en fonction de la largeur de la viewport.                                       | `<img>`, `<source>`                            | `sizes="(max-width: 600px) 480px, 800px"`                                                           | Oui       |
#  |                             | `crossorigin`                | Contrôle les requêtes CORS pour les images.                                                        | `<img>`, `<script>`, `<link>`, `<video>`      | `crossorigin="anonymous"`, `use-credentials`                                                        | Oui       |
#  |                             | `ismap` / `usemap`           | Images cliquables (side server/client).                                                          | `<img>`                                        | `ismap` (serveur), `usemap="#map-name"` (client, avec `<map>`)                                       | Oui       |
#  |                             | `controls`                  | Affiche les contrôles pour les médias.                                                            | `<audio>`, `<video>`                          | `controls` (pas de valeur)                                                                          | Oui       |
#  |                             | `autoplay`                   | Lecture automatique.                                                                               | `<audio>`, `<video>`                          | `autoplay` (souvent bloqué par les navigateurs sans `muted`)                                         | Oui       |
#  |                             | `loop`                       | Lecture en boucle.                                                                                 | `<audio>`, `<video>`                          | `loop`                                                                                              | Oui       |
#  |                             | `muted`                      | Désactive le son.                                                                                 | `<audio>`, `<video>`                          | `muted`                                                                                              | Oui       |
#  |                             | `poster`                     | Image de prévisualisation pour les vidéos.                                                        | `<video>`                                     | `poster="poster.jpg"`                                                                               | Oui       |
#  |                             | `preload`                    | Préchargement du média.                                                                             | `<audio>`, `<video>`                          | `preload="none"` (désactivé), `metadata` (métadonnées uniquement), `auto` (défaut)                 | Oui       |
#  | **📝 Formulaires**          | `action`                     | URL de soumission du formulaire.                                                                   | `<form>`                                      | `action="/submit"`                                                                                   | Oui       |
#  |                             | `method`                     | Méthode HTTP pour la soumission.                                                                  | `<form>`                                      | `method="get"` (défaut), `post`, `dialog` (HTML5)                                                    | Oui       |
#  |                             | `enctype`                    | Type de codage des données du formulaire.                                                         | `<form>`                                      | `enctype="application/x-www-form-urlencoded"` (défaut), `multipart/form-data` (fichiers), `text/plain` | Oui       |
#  |                             | `name`                       | Nom du champ (utilisé pour la soumission).                                                        | `<input>`, `<textarea>`, `<select>`, `<button>`, `<form>`, `<fieldset>`, `<output>` | `name="username"`                                                                               | Oui       |
#  |                             | `value`                      | Valeur par défaut ou soumise.                                                                      | `<input>`, `<option>`, `<button>`, `<textarea>`, `<select>` | `value="Soumettre"` (pour `<button>`), `value="option1"` (pour `<option>`)                        | Oui       |
#  |                             | `type`                       | Type de champ de formulaire.                                                                       | `<input>`, `<button>`                         | `type="text"`, `password`, `email`, `number`, `date`, `checkbox`, `radio`, `file`, `submit`, `hidden` | Oui       |
#  |                             | `placeholder`                 | Texte d'exemple (disparaît à la saisie).                                                          | `<input>`, `<textarea>`                      | `placeholder="Entrez votre nom"`                                                                   | Oui       |
#  |                             | `required`                   | Champ obligatoire.                                                                               | `<input>`, `<textarea>`, `<select>`           | `required`                                                                                          | Oui       |
#  |                             | `readonly`                   | Champ en lecture seule (modifiable via JS).                                                       | `<input>`, `<textarea>`                      | `readonly`                                                                                          | Oui       |
#  |                             | `disabled`                   | Désactive le champ (non modifiable, non soumis).                                                  | `<input>`, `<textarea>`, `<select>`, `<button>`, `<fieldset>`, `<optgroup>`, `<option>` | `disabled` | Oui       |
#  |                             | `autofocus`                   | Focus automatique au chargement de la page.                                                       | `<input>`, `<textarea>`, `<select>`, `<button>` | `autofocus`                                                                                     | Oui       |
#  |                             | `autocomplete`                | Active/désactive l'autocomplétion.                                                                | `<input>`, `<textarea>`, `<select>`, `<form>` | `autocomplete="on"` (défaut), `off`, `name`, `email`, `address-level1` (pays), etc.               | Oui       |
#  |                             | `min` / `max`                 | Valeurs minimale/maximale (pour `type="number"`, `date`, etc.).                                   | `<input>`                                     | `min="0"`, `max="100"`                                                                              | Oui       |
#  |                             | `step`                       | Incrément pour les champs numériques.                                                             | `<input type="number" step="0.1">`          | `step="1"` (défaut), `step="0.01"`                                                                  | Oui       |
#  |                             | `pattern`                    | Expression régulière pour validation.                                                            | `<input type="text">`                         | `pattern="[A-Za-z]+"` (lettres uniquement)                                                        | Oui       |
#  |                             | `size`                       | Taille visible du champ (en caractères).                                                          | `<input>`, `<select>`                         | `size="20"`                                                                                         | Oui       |
#  |                             | `maxlength`                   | Nombre maximal de caractères.                                                                     | `<input>`, `<textarea>`                      | `maxlength="50"`                                                                                   | Oui       |
#  |                             | `minlength`                   | Nombre minimal de caractères.                                                                     | `<input>`, `<textarea>`                      | `minlength="5"`                                                                                     | Oui       |
#  |                             | `multiple`                   | Autorise plusieurs valeurs.                                                                     | `<input type="file"|email">`, `<select>`      | `multiple`                                                                                         | Oui       |
#  |                             | `checked`                    | Case cochée par défaut.                                                                           | `<input type="checkbox"|radio">`               | `checked`                                                                                          | Oui       |
#  |                             | `selected`                    | Option sélectionnée par défaut.                                                                  | `<option>`                                    | `selected`                                                                                          | Oui       |
#  |                             | `cols` / `rows`               | Dimensions d'un `<textarea>` (colonnes/lignes).                                                   | `<textarea>`                                 | `cols="50"`, `rows="5"`                                                                             | Oui       |
#  |                             | `wrap`                       | Comportement du retour à la ligne dans `<textarea>`.                                              | `<textarea>`                                 | `wrap="soft"` (défaut, retour à la ligne dans l'UI mais pas dans la valeur), `hard` (inclus dans la valeur) | Oui       |
#  |                             | `for`                        | Associe un `<label>` à un champ de formulaire.                                                    | `<label>`                                    | `for="username"` (doit correspondre à l'`id` du champ)                                              | Oui       |
#  | **📊 Tableaux**             | `colspan`                     | Fusionne des cellules horizontalement.                                                           | `<td>`, `<th>`                               | `colspan="2"`                                                                                      | Oui       |
#  |                             | `rowspan`                     | Fusionne des cellules verticalement.                                                             | `<td>`, `<th>`                               | `rowspan="3"`                                                                                      | Oui       |
#  |                             | `scope`                       | Définit la portée d'un en-tête de tableau (accessibilité).                                       | `<th>`                                       | `scope="col"` (colonne), `row` (ligne), `colgroup`, `rowgroup`                                      | Oui       |
#  | **🎨 Styles & Scripts**      | `rel`                         | Relation entre le document et la ressource.                                                     | `<link>`, `<a>`, `<area>`                     | `rel="stylesheet"` (CSS), `rel="icon"` (favicon), `rel="preload"` (préchargement)                | Oui       |
#  |                             | `type`                        | Type de la ressource.                                                                             | `<script>`, `<style>`, `<link>`, `<object>`, `<source>` | `type="text/javascript"` (défaut pour `<script>`), `type="text/css"` (pour `<style>`)           | Oui       |
#  |                             | `async` / `defer`              | Contrôle le chargement des scripts.                                                               | `<script>`                                   | `async` (exécution asynchrone), `defer` (exécution après le DOM)                                  | Oui       |
#  |                             | `integrity`                   | Vérification de l'intégrité des ressources (SRI).                                               | `<script>`, `<link>`                          | `integrity="sha384-..."` + `crossorigin="anonymous"`                                               | Oui       |
#  |                             | `nonce`                       | Autorise l'exécution d'un script (CSP).                                                          | `<script>`, `<style>`                        | `nonce="EDNnf03nceIOfn39fn3e9h3sdfa"`                                                             | Oui       |
#  | **📱 Responsif & Médias**   | `media`                        | Requête média pour les styles ou scripts.                                                        | `<link>`, `<style>`, `<source>` (dans `<picture>`) | `media="(max-width: 600px)"`                                                                       | Oui       |
#  |                             | `sizes`                        | Taille de l'image en fonction de la viewport (pour `<source>` dans `<picture>`).                  | `<source>` (dans `<picture>`)                 | `sizes="(max-width: 600px) 480px, 800px"`                                                           | Oui       |
#  | **🔌 Iframes & Intégrations** | `sandbox`                     | Restrictions de sécurité pour les iframes.                                                       | `<iframe>`                                   | `sandbox=""` (toutes les restrictions), `sandbox="allow-scripts allow-forms"`                  | Oui       |
#  |                             | `allow`                       | Autorise des fonctionnalités spécifiques dans une iframe.                                      | `<iframe>`                                   | `allow="geolocation; microphone"` (pour les APIs)                                                 | Oui       |
#  |                             | `allowfullscreen`             | Autorise le mode plein écran.                                                                     | `<iframe>`                                   | `allowfullscreen`                                                                                 | Oui       |
#  |                             | `frameborder`                 | **Dépécié** : Bordure de l'iframe (utilisez CSS `border` à la place).                             | `<iframe>`                                   | `frameborder="0"` (plus de bordure)                                                              | Non        |
#  | **📌 Métadonnées**          | `charset`                      | Encodage des caractères.                                                                          | `<meta>`                                     | `charset="UTF-8"`                                                                                  | Oui       |
#  |                             | `name` / `content`             | Nom et contenu d'une méta-donnée.                                                                | `<meta>`                                     | `<meta name="description" content="Ma page">`                                                     | Oui       |
#  |                             | `http-equiv`                  | Équivalent HTTP pour les méta-données.                                                           | `<meta>`                                     | `<meta http-equiv="X-UA-Compatible" content="IE=edge">`                                         | Oui       |
#  |                             | `viewport`                     | Contrôle l'affichage sur mobile.                                                                   | `<meta>`                                     | `<meta name="viewport" content="width=device-width, initial-scale=1.0">`                          | Oui       |
#  | **🎯 Événements**           | `on*` (ex: `onclick`)         | Attributs d'événements (en ligne). **À éviter** (préférez `addEventListener`).                   | Toutes (sauf quelques exceptions)           | `onclick="alert('Cliqué !')"`                                                                     | Oui       |
#  |                             | Exemples :                    | `onload`, `onerror`, `onfocus`, `onblur`, `onchange`, `onsubmit`, `onkeydown`, `onmouseover`, etc. | Toutes                                         | `onload="init()"`                                                                                 | Oui       |

# %% [markdown]
# # Principales propriétés et selecteurs CSS
#
#   **Catégorie**               | **Propriété/Sélecteur**       | **Description**                                                                                     | **Valeurs/Exemples**                                                                                     | **Héritage** |
#  |-----------------------------|-------------------------------|-----------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------|--------------|
#  | **Sélecteurs**              | `*`                           | Sélectionne tous les éléments.                                                                     | `* { margin: 0; }`                                                                                       | Non          |
#  |                             | `element`                     | Sélectionne tous les éléments de ce type.                                                           | `p { color: blue; }`                                                                                     | Oui          |
#  |                             | `.class`                      | Sélectionne tous les éléments avec une classe spécifique.                                          | `.ma-classe { font-size: 16px; }`                                                                     | Oui          |
#  |                             | `#id`                         | Sélectionne un élément par son ID (unique).                                                         | `#mon-id { background: red; }`                                                                          | Non          |
#  |                             | `selector1, selector2`       | Sélectionne plusieurs éléments.                                                                   | `h1, h2, h3 { color: green; }`                                                                          | Oui          |
#  |                             | `element class`               | Sélectionne les éléments d'un type avec une classe.                                               | `p.important { font-weight: bold; }`                                                                  | Oui          |
#  |                             | `element:state`              | Sélectionne un élément dans un état spécifique (pseudo-classes).                                   | `a:hover { color: red; }`, `:active`, `:focus`, `:checked`, `:disabled`                              | Oui          |
#  |                             | `element::pseudo`             | Sélectionne une partie spécifique d'un élément (pseudo-éléments).                                  | `p::first-line { text-transform: uppercase; }`, `::before`, `::after`, `::selection`                | Oui          |
#  |                             | `[attribute]`                 | Sélectionne les éléments avec un attribut spécifique.                                              | `[type="text"] { border: 1px solid #ccc; }`                                                             | Non          |
#  |                             | `parent > child`              | Sélectionne les enfants directs.                                                                  | `div > p { color: orange; }`                                                                             | Oui          |
#  |                             | `ancestor descendant`        | Sélectionne tous les descendants (pas seulement les enfants directs).                              | `div p { margin: 10px; }`                                                                                | Oui          |
#  |                             | `element + next`              | Sélectionne l'élément **immédiatement après** un autre.                                            | `h2 + p { font-style: italic; }`                                                                        | Non          |
#  |                             | `element ~ siblings`          | Sélectionne tous les **frères** qui suivent.                                                       | `h2 ~ p { background: #f0f0f0; }`                                                                       | Non          |
#  | **Polices**                 | `font-family`                 | Définit la famille de police.                                                                     | `font-family: Arial, sans-serif;`                                                                       | Oui          |
#  |                             | `font-size`                   | Taille de la police.                                                                               | `font-size: 16px;`, `1em`, `100%`, `clamp(12px, 2vw, 20px)`                                           | Oui          |
#  |                             | `font-weight`                 | Épaisseur de la police.                                                                           | `font-weight: normal;`, `bold;`, `100` à `900`                                                          | Oui          |
#  |                             | `font-style`                  | Style de la police.                                                                               | `font-style: italic;`, `oblique;`, `normal;`                                                             | Oui          |
#  |                             | `text-transform`              | Transforme le texte.                                                                               | `text-transform: uppercase;`, `capitalize;`, `lowercase;`                                              | Oui          |
#  |                             | `line-height`                 | Hauteur de ligne.                                                                                 | `line-height: 1.5;`, `20px;`                                                                             | Oui          |
#  |                             | `letter-spacing`              | Espacement entre les caractères.                                                                   | `letter-spacing: 1px;`                                                                                  | Oui          |
#  |                             | `text-align`                  | Alignement horizontal du texte.                                                                   | `text-align: center;`, `left;`, `right;`, `justify;`                                                    | Oui          |
#  |                             | `text-decoration`             | Décoration du texte.                                                                               | `text-decoration: underline;`, `none;`, `line-through;`                                                | Non          |
#  |                             | `color`                        | Couleur du texte.                                                                                 | `color: #ff0000;`, `rgb(255, 0, 0);`, `hsl(0, 100%, 50%);`, `var(--ma-couleur);`                        | Oui          |
#  | **Boîte (Box Model)**       | `width` / `height`             | Largeur et hauteur.                                                                               | `width: 100%;`, `height: 200px;`                                                                       | Non          |
#  |                             | `margin`                       | Marge extérieure.                                                                                | `margin: 10px;`, `margin: 5px 10px;`, `margin-top: 20px;`                                             | Non          |
#  |                             | `padding`                      | Espacement intérieur.                                                                             | `padding: 15px;`, `padding: 10px 20px;`                                                                | Non          |
#  |                             | `border`                       | Bordure.                                                                                          | `border: 1px solid black;`, `border-radius: 5px;`                                                    | Non          |
#  |                             | `border-radius`                | Arrondi des coins.                                                                               | `border-radius: 5px;`, `border-radius: 50%` (cercle)                                                   | Non          |
#  |                             | `box-shadow`                   | Ombre portée.                                                                                     | `box-shadow: 2px 2px 5px rgba(0,0,0,0.3);`                                                             | Non          |
#  |                             | `box-sizing`                   | Définit comment calculer la taille totale (inclut padding/border ou non).                           | `box-sizing: border-box;` (recommandé)                                                                  | Non          |
#  | **Affichage & Position**   | `display`                      | Type d'affichage.                                                                                 | `display: block;`, `inline;`, `inline-block;`, `flex;`, `grid;`, `none;`                              | Non          |
#  |                             | `visibility`                   | Visibilité.                                                                                       | `visibility: hidden;` (espace réservé), `visible;`                                                    | Oui          |
#  |                             | `opacity`                      | Transparence (0 à 1).                                                                             | `opacity: 0.5;`                                                                                         | Oui          |
#  |                             | `position`                     | Positionnement.                                                                                   | `position: static;`, `relative;`, `absolute;`, `fixed;`, `sticky;`                                     | Non          |
#  |                             | `top` / `right` / `bottom` / `left` | Position par rapport au parent positionné.                                      | `top: 10px;`, `left: 0;`                                                                               | Non          |
#  |                             | `z-index`                      | Ordre d'empilement (pour `position: absolute/fixed/sticky`).                                      | `z-index: 10;`                                                                                         | Non          |
#  |                             | `overflow`                     | Comportement en cas de dépassement.                                                               | `overflow: hidden;`, `scroll;`, `auto;`                                                                 | Non          |
#  | **Flexbox**                  | `display: flex`                | Active le mode flex.                                                                              | `display: flex;`                                                                                         | Non          |
#  |                             | `flex-direction`               | Direction des éléments flex.                                                                       | `flex-direction: row;` (défaut), `row-reverse;`, `column;`, `column-reverse;`                         | Non          |
#  |                             | `justify-content`             | Alignement principal (axe horizontal par défaut).                                                 | `justify-content: center;`, `flex-start;`, `space-between;`, `space-around;`                           | Non          |
#  |                             | `align-items`                  | Alignement transversal (axe vertical par défaut).                                                 | `align-items: center;`, `flex-start;`, `stretch;`                                                       | Non          |
#  |                             | `flex-wrap`                     | Autorise le retour à la ligne.                                                                    | `flex-wrap: wrap;` (défaut: `nowrap`)                                                                   | Non          |
#  |                             | `align-content`                | Alignement des lignes (si `flex-wrap: wrap`).                                                      | `align-content: center;`, `space-between;`                                                             | Non          |
#  |                             | `flex-grow`                    | Permet à un élément de grandir pour occuper l'espace disponible.                                   | `flex-grow: 1;` (défaut: `0`)                                                                         | Non          |
#  |                             | `flex-shrink`                  | Permet à un élément de rétrécir si nécessaire.                                                     | `flex-shrink: 1;` (défaut)                                                                               | Non          |
#  |                             | `flex-basis`                   | Taille initiale avant croissance/rétrécissement.                                                  | `flex-basis: 100px;`                                                                                   | Non          |
#  |                             | `order`                        | Ordre des éléments flex.                                                                           | `order: 2;` (défaut: `0`)                                                                               | Non          |
#  | **CSS Grid**                 | `display: grid`                | Active le mode grid.                                                                              | `display: grid;`                                                                                         | Non          |
#  |                             | `grid-template-columns`       | Définit les colonnes de la grille.                                                               | `grid-template-columns: 1fr 2fr;` ou `repeat(3, 1fr)`                                                  | Non          |
#  |                             | `grid-template-rows`          | Définit les lignes de la grille.                                                                  | `grid-template-rows: auto 1fr;`                                                                         | Non          |
#  |                             | `gap` / `row-gap` / `column-gap` | Espacement entre les éléments.                                                                   | `gap: 10px;` ou `row-gap: 5px; column-gap: 15px;`                                                      | Non          |
#  |                             | `grid-column` / `grid-row`     | Positionne un élément dans la grille.                                                            | `grid-column: 1 / 3;` ou `grid-column: span 2;`                                                        | Non          |
#  |                             | `grid-area`                    | Définit la zone d'un élément (pour les templates de zone).                                          | `grid-area: header;` ou `grid-area: 1 / 1 / 3 / 4;`                                                   | Non          |
#  |                             | `grid-template-areas`         | Définit un template de zones nommées.                                                             | `grid-template-areas: "header header" "sidebar main";`                                                 | Non          |
#  |                             | `justify-items` / `align-items` | Alignement des éléments dans leurs cellules.                                                     | `justify-items: center;` (axe horizontal), `align-items: end;` (axe vertical)                          | Non          |
#  | **Couleurs & Arrière-plans** | `background-color`            | Couleur de fond.                                                                                 | `background-color: #f0f0f0;`                                                                             | Non          |
#  |                             | `background-image`             | Image de fond.                                                                                   | `background-image: url('image.jpg');`                                                                   | Non          |
#  |                             | `background-size`              | Taille de l'image de fond.                                                                       | `background-size: cover;`, `contain;`, `50% 50%;`                                                       | Non          |
#  |                             | `background-position`         | Position de l'image de fond.                                                                     | `background-position: center;`, `top left;`                                                             | Non          |
#  |                             | `background-repeat`           | Répétition de l'image de fond.                                                                   | `background-repeat: no-repeat;` ou `repeat-x;`                                                          | Non          |
#  |                             | `background`                    | raccourci pour toutes les propriétés de fond.                                                   | `background: #fff url('img.jpg') no-repeat center/cover;`                                             | Non          |
#  |                             | `gradient`                      | Dégradé de couleurs.                                                                             | `background: linear-gradient(to right, #ff0000, #0000ff);`                                            | Non          |
#  | **Transformations**         | `transform`                     | Applique une transformation 2D/3D.                                                              | `transform: rotate(45deg);`, `scale(1.5);`, `translateX(10px);`                                         | Non          |
#  |                             | `transition`                   | Animation fluide entre deux états.                                                               | `transition: all 0.3s ease;` ou `transition: opacity 0.5s linear;`                                     | Non          |
#  |                             | `animation`                    | Animation personnalisée.                                                                         | `animation: nom 2s infinite;` (avec `@keyframes nom { ... }`)                                           | Non          |
#  | **Mise en page**            | `float`                         | Flottement (dépassé par Flexbox/Grid).                                                            | `float: left;` ou `right;`                                                                               | Non          |
#  |                             | `clear`                         | Empêche le flottement d'un côté.                                                                 | `clear: both;` ou `left;`                                                                                | Non          |
#  | **Unités**                  | -                             | Unités courantes :                                                                               | `px`, `%`, `em`, `rem`, `vw`, `vh`, `vmin`, `vmax`, `clamp()`, `min()`, `max()`                         | -            |
#  | **Variables CSS**           | `--var`                        | Définit une variable personnalisée.                                                             | `--ma-couleur: #ff0000;` (dans `:root` ou un sélecteur)                                                  | Oui          |
#  |                             | `var()`                        | Utilise une variable.                                                                           | `color: var(--ma-couleur);`                                                                             | Oui          |
#  | **Responsive Design**      | `@media`                       | Règles conditionnelles selon la taille de l'écran.                                               | `@media (max-width: 768px) { body { font-size: 14px; } }`                                            | -            |
#  |                             | `@supports`                    | Règles conditionnelles selon la prise en charge d'une propriété.                                  | `@supports (display: grid) { ... }`                                                                     | -            |

# %% [markdown]
# # Principaux concepts, méthodes et propriétés
#
#   **Catégorie**               | **Éléments**                     | **Description**                                                                                     | **Exemples**                                                                                     |
#  |-----------------------------|----------------------------------|-----------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------|
#  | **📌 Types de données**      | `Number`                         | Nombre (entier ou décimal).                                                                       | `let age = 25;`, `let pi = 3.14;`                                                               |
#  |                             | `String`                         | Chaîne de caractères.                                                                              | `let name = "Alice";`, `` `Template ${name}` ``                                                  |
#  |                             | `Boolean`                        | Vrai (`true`) ou faux (`false`).                                                                   | `let isValid = true;`                                                                          |
#  |                             | `Null` / `Undefined`             | `null` (vide intentionnel), `undefined` (variable non définie).                                   | `let x = null;`, `let y;` (→ `undefined`)                                                       |
#  |                             | `Symbol`                         | Valeur unique et immuable (ES6).                                                                  | `const sym = Symbol('id');`                                                                   |
#  |                             | `BigInt`                         | Entiers très grands (ES11).                                                                       | `const big = 123456789012345678901234567890n;`                                                   |
#  |                             | `Object`                         | Objet (clé: valeur).                                                                               | `const user = { name: "Bob", age: 30 };`                                                      |
#  |                             | `Array`                          | Tableau (liste ordonnée).                                                                         | `const arr = [1, 2, 3];`, `const mixed = [1, "two", true];`                                     |
#  |                             | `Function`                       | Fonction (objet callable).                                                                         | `function greet() { return "Hello"; }`, `const arrow = () => {};`                               |
#  | **🔢 Opérateurs**           | Arithmétiques                    | `+`, `-`, `*`, `/`, `%` (modulo), `**` (puissance).                                                | `5 % 2` → `1`, `2 ** 3` → `8`                                                                  |
#  |                             | Comparaison                      | `==` (égalité lâche), `===` (égalité stricte), `!=`, `!==`, `>`, `<`, `>=`, `<=`.                 | `5 === "5"` → `false`, `5 == "5"` → `true`                                                     |
#  |                             | Logiques                         | `&&` (ET), `\|\|` (OU), `!` (NON).                                                                  | `true && false` → `false`, `!true` → `false`                                                    |
#  |                             | Ternaire                         | Condition ? valeurSiVrai : valeurSiFaux.                                                          | `age >= 18 ? "Adulte" : "Mineur"`                                                             |
#  |                             | Spread (`...`)                   | Décompose un tableau/objet.                                                                        | `[...arr, 4]` (ajoute 4 à `arr`), `{ ...obj, key: "new" }`                                       |
#  |                             | Destructuring                    | Extraire des valeurs d'un tableau/objet.                                                          | `const [a, b] = [1, 2];`, `const { name } = user;`                                              |
#  | **🎯 Structures de contrôle** | `if...else`                     | Conditionnelle.                                                                                   | `if (x > 0) { ... } else if (x < 0) { ... } else { ... }`                                     |
#  |                             | `switch`                         | Sélection multiple.                                                                               | `switch (day) { case 0: ... break; default: ... }`                                             |
#  |                             | `for`                            | Boucle avec initialisation, condition, incrément.                                                 | `for (let i = 0; i < 5; i++) { ... }`                                                          |
#  |                             | `while` / `do...while`           | Boucle conditionnelle.                                                                             | `while (condition) { ... }`, `do { ... } while (condition);`                                   |
#  |                             | `for...in`                       | Itère sur les **clés** d'un objet.                                                                | `for (let key in obj) { console.log(key); }`                                                   |
#  |                             | `for...of`                       | Itère sur les **valeurs** d'un tableau/itérable.                                                  | `for (let item of arr) { console.log(item); }`                                                 |
#  | **📦 Tableaux (Array)**      | `length`                         | Longueur du tableau.                                                                              | `arr.length`                                                                                   |
#  |                             | `push()` / `pop()`               | Ajoute/supprime à la **fin**.                                                                     | `arr.push(4);` → `[1,2,3,4]`, `arr.pop()` → `4` (retire et retourne)                           |
#  |                             | `unshift()` / `shift()`          | Ajoute/supprime au **début**.                                                                     | `arr.unshift(0);` → `[0,1,2,3]`, `arr.shift()` → `0`                                           |
#  |                             | `slice()`                        | Copie une partie du tableau.                                                                      | `arr.slice(1, 3)` → `[2,3]` (de l'index 1 à 2)                                                 |
#  |                             | `splice()`                       | Modifie le tableau (ajoute/supprime).                                                             | `arr.splice(1, 2, "a")` → supprime 2 éléments à l'index 1 et ajoute `"a"`                      |
#  |                             | `concat()`                       | Fusionne des tableaux.                                                                           | `[1,2].concat([3,4])` → `[1,2,3,4]`                                                           |
#  |                             | `join()`                         | Convertit en chaîne avec séparateur.                                                              | `arr.join("-")` → `"1-2-3"`                                                                     |
#  |                             | `indexOf()` / `lastIndexOf()`    | Trouve l'index d'une valeur.                                                                      | `arr.indexOf(2)` → `1`, `arr.lastIndexOf(2)` → `1`                                             |
#  |                             | `includes()`                     | Vérifie si une valeur existe.                                                                     | `arr.includes(2)` → `true`                                                                     |
#  |                             | `find()` / `findIndex()`         | Trouve le **premier élément/indice** correspondant à une condition.                               | `arr.find(x => x > 1)` → `2`, `arr.findIndex(x => x > 1)` → `1`                                |
#  |                             | `filter()`                       | Crée un nouveau tableau avec les éléments filtrés.                                              | `arr.filter(x => x > 1)` → `[2,3]`                                                             |
#  |                             | `map()`                          | Applique une fonction à chaque élément.                                                           | `arr.map(x => x * 2)` → `[2,4,6]`                                                             |
#  |                             | `reduce()`                       | Réduit le tableau à une seule valeur.                                                            | `arr.reduce((acc, x) => acc + x, 0)` → `6` (somme)                                              |
#  |                             | `sort()`                         | Trie le tableau (par défaut en chaîne de caractères).                                            | `arr.sort((a, b) => a - b)` → `[1,2,3]` (tri numérique)                                         |
#  |                             | `reverse()`                      | Inverse l'ordre du tableau.                                                                       | `arr.reverse()` → `[3,2,1]`                                                                   |
#  |                             | `every()` / `some()`             | Vérifie si **tous**/`au moins un` élément satisfait une condition.                              | `arr.every(x => x > 0)` → `true`, `arr.some(x => x > 2)` → `true`                               |
#  | **📚 Objets**                | `Object.keys()` / `values()` / `entries()` | Récupère les clés/valeurs/paires clé-valeur.                                    | `Object.keys(obj)` → `["name", "age"]`                                                          |
#  |                             | `Object.assign()`                | Copie les propriétés d'un objet vers un autre.                                                   | `Object.assign({}, obj1, obj2)` (fusion)                                                      |
#  |                             | `Object.freeze()` / `seal()`    | Empêche les modifications (`freeze`: pas d'ajout/suppression, `seal`: pas d'ajout).          | `Object.freeze(obj);`                                                                          |
#  |                             | `hasOwnProperty()`              | Vérifie si une propriété existe.                                                                 | `obj.hasOwnProperty("name")` → `true`                                                          |
#  | **🔄 Fonctions**             | Déclaration                     | Fonction nommée.                                                                                   | `function foo() { return "bar"; }`                                                             |
#  |                             | Expression                      | Fonction anonyme.                                                                                  | `const foo = function() { return "bar"; };`                                                    |
#  |                             | Fléchée (Arrow)                 | Fonction sans `this` propre (ES6).                                                                | `const foo = () => "bar";`                                                                     |
#  |                             | Paramètres par défaut           | Valeurs par défaut pour les paramètres.                                                           | `function greet(name = "User") { ... }`                                                        |
#  |                             | Rest Parameters (`...`)         | Regroupe les arguments restants dans un tableau.                                                 | `function sum(...nums) { return nums.reduce((a, b) => a + b); }`                               |
#  |                             | `arguments`                     | Objet similaire à un tableau (dépassé par `...rest`).                                             | `function foo() { console.log(arguments[0]); }`                                                |
#  |                             | `this`                          | Contexte de la fonction (objet appelant).                                                         | `const obj = { method() { console.log(this); } };`                                             |
#  |                             | `bind()` / `call()` / `apply()`  | Modifie le contexte (`this`).                                                                     | `func.bind(obj)`, `func.call(obj, arg1)`, `func.apply(obj, [arg1, arg2])`                     |
#  | **🕒 Asynchrone**            | `setTimeout()`                  | Exécute une fonction après un délai.                                                            | `setTimeout(() => console.log("Hi"), 1000);` (1 seconde)                                       |
#  |                             | `setInterval()`                 | Exécute une fonction à intervalles réguliers.                                                   | `setInterval(() => console.log("Hi"), 1000);` (toutes les 1 seconde)                          |
#  |                             | `Promise`                        | Objet représentant une opération asynchrone.                                                    | `new Promise((resolve, reject) => { resolve("Success"); })`                                   |
#  |                             | `.then()` / `.catch()`           | Gère le succès/échec d'une promesse.                                                              | `promise.then(data => console.log(data)).catch(err => console.error(err));`                  |
#  |                             | `async/await`                   | Syntaxe plus lisible pour les promesses (ES8).                                                    | `async function fetchData() { const res = await fetch(url); }`                                  |
#  |                             | `fetch()`                        | Requête HTTP (remplace `XMLHttpRequest`).                                                         | `fetch(url).then(res => res.json()).then(data => console.log(data));`                         |
#  | **🌐 DOM (Manipulation)**   | `document.querySelector()`      | Sélectionne le **premier** élément correspondant.                                               | `document.querySelector(".class")` → premier élément avec la classe `class`.                  |
#  |                             | `document.querySelectorAll()`   | Sélectionne **tous** les éléments correspondants.                                                | `document.querySelectorAll("p")` → NodeList de tous les `<p>`.                                |
#  |                             | `element.textContent`          | Texte brut d'un élément.                                                                         | `element.textContent = "Hello";`                                                              |
#  |                             | `element.innerHTML`            | HTML d'un élément (risque XSS).                                                                   | `element.innerHTML = "<strong>Hello</strong>";`                                               |
#  |                             | `element.setAttribute()`       | Définit un attribut.                                                                              | `element.setAttribute("id", "myId");`                                                        |
#  |                             | `element.getAttribute()`       | Récupère un attribut.                                                                             | `element.getAttribute("id")` → `"myId"`                                                       |
#  |                             | `element.addEventListener()`   | Ajoute un écouteur d'événement.                                                                  | `element.addEventListener("click", () => console.log("Clicked!"));`                           |
#  |                             | `element.style`                | Modifie le style CSS.                                                                             | `element.style.color = "red";`                                                                |
#  |                             | `element.classList`            | Gère les classes CSS.                                                                             | `element.classList.add("active");`, `remove("old")`, `toggle("hidden")`                        |
#  | **📊 Classes (ES6)**          | `class`                          | Définit une classe.                                                                               | `class User { constructor(name) { this.name = name; } }`                                       |
#  |                             | `extends`                       | Héritage de classe.                                                                               | `class Admin extends User { ... }`                                                             |
#  |                             | `super`                         | Appelle le constructeur/une méthode de la classe parente.                                       | `super();`, `super.method();`                                                                 |
#  |                             | Méthodes statiques (`static`)   | Méthode appelée sur la classe, pas sur une instance.                                             | `static countUsers() { return User.users.length; }`                                            |
#  | **🗃️ Stockage**              | `localStorage`                  | Stockage persistant (par domaine).                                                               | `localStorage.setItem("key", "value");`, `localStorage.getItem("key")`                         |
#  |                             | `sessionStorage`                | Stockage temporaire (session).                                                                    | `sessionStorage.setItem("key", "value");`                                                     |
#  |                             | `JSON.parse()` / `JSON.stringify()` | Convertit JSON ↔ objet.                                                                     | `JSON.parse('{"name":"Alice"}')`, `JSON.stringify(obj)`                                         |
#  | **🛠️ Modules (ES6)**          | `import` / `export`             | Importe/exporte des fonctionnalités entre fichiers.                                             | `export const foo = 1;`, `import { foo } from './module.js';`                                  |
#  | **🔧 Outils modernes**        | `Optional Chaining` (`?.`)      | Accès sécurisé aux propriétés (évite les erreurs si `undefined`).                              | `user?.address?.city` (retourne `undefined` si `user` ou `address` est `null/undefined`)         |
#  |                             | `Nullish Coalescing` (`??`)     | Opérateur de coalescence nulle.                                                                  | `const x = null ?? "default";` → `"default"` (seulement si `null` ou `undefined`)               |
#  | **📝 Bonnes pratiques**       | `const` / `let`                 | Préférer à `var` (portée de bloc).                                                                | `const PI = 3.14;` (constante), `let x = 10;` (variable)                                       |
#  |                             | Déstructuration                 | Extraire des données de manière lisible.                                                         | `const { name, age } = user;`                                                                 |
#  |                             | Template Literals               | Chaînes de caractères multi-lignes et interpolées.                                              | `` `Hello ${name}, you are ${age} years old` ``                                                                   |

# %% [markdown]
# # Récapitulatif général des commandes de base
#
# |                     **Commande**                    |                          **Résultat**                     |
# |:---------------------------------------------------:|:---------------------------------------------------------:|
# | print()                                             | Afficher un message                                       |
# | nom_variable = 2024                                 | Assigner 2024 à la variable nom_variable                  |
# | type()                                              | Donner le type d’une variable                             |
# | str() ; int() ; float() ; bool()                    | Convertir le type d’une donnée                            |
# | + ; - ; * ; / ; // ; % ; ** ; < ; <= ; == ; >= ; >  | Opérateurs arithmétiques et logiques                      |
# | # …                                                 | Commentaires                                            |
# | nom_variable = []                                   | Créer une liste                                           |
# | .append(n)                                          | Ajouter n à la fin d'une liste                            |
# | del nom_variable [n]                              | Retirer l’élément n d’une liste                           |
# | len()                                               | Donner la longueur d’une variable                         |
# | nom_variable = {}                                   | Créer un dictionnaire                                     |
# | nom_variable ["clé"] = "valeur"                   | Ajouter une valeur et une clé à un dictionnaire           |
# | .keys()  ; .values() ; .items()                     | Récupérer les clés ; les valeurs ; ou le tuple clé/valeur |
# | if … ((not) in):  elif … : else :                   | Test/Condition                                            |
# | for … in … : ;  for … in range (…) : ;  while … :   | Boucles/Iterations                                        |
# | def nom_fonction() :         return                 | Définir une fonction ; Eventuellement retourner une valeur|
